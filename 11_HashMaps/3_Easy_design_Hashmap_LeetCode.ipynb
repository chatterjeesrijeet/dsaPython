# %% [markdown]
# ![Screenshot%202021-07-27%20at%2010.20.08%20PM.png](attachment:Screenshot%202021-07-27%20at%2010.20.08%20PM.png)

# %% [markdown]
# The below Implementation is slow actually

# %%
class MyHashMap:

    def __init__(self):
        """
        Initialize your data structure here.
        """
        self.hmap = []

    def put(self, key: int, value: int) -> None:
        """
        value will always be non-negative.
        """
        for ele in self.hmap:
            if ele[0]==key:
                ele[1] = value
                return
        
        self.hmap.append([key,value])
        return
        

    def get(self, key: int) -> int:
        """
        Returns the value to which the specified key is mapped, or -1 if this map contains no mapping for the key
        """
        for ele in self.hmap:
            if ele[0]==key:
                return ele[1]
        return -1
        

    def remove(self, key: int) -> None:
        """
        Removes the mapping of the specified value key if this map contains a mapping for the key
        """
        
        for i,ele in enumerate(self.hmap):
            if ele[0]==key:
                self.hmap.pop(i)
                return
        return
        


# Your MyHashMap object will be instantiated and called as such:
# obj = MyHashMap()
# obj.put(key,value)
# param_2 = obj.get(key)
# obj.remove(key)

# %% [markdown]
# ![Screenshot%202021-07-27%20at%2010.19.27%20PM.png](attachment:Screenshot%202021-07-27%20at%2010.19.27%20PM.png)

# %% [markdown]
#                 Much Much faster Solution

# %%
class MyHashMap:
    
    def __init__(self):
        self.d = dict()

    def put(self, key: int, value: int) -> None:
        self.d[key] = value

    def get(self, key: int) -> int:
        if key in self.d:
            return self.d[key]
        return -1
        

    def remove(self, key: int) -> None:
        if key in self.d:
            del self.d[key]

# %% [markdown]
# ![Screenshot%202021-07-27%20at%2010.32.05%20PM.png](attachment:Screenshot%202021-07-27%20at%2010.32.05%20PM.png)
