# %% [markdown]
# ![Screenshot%202021-09-14%20at%2010.43.47%20PM.png](attachment:Screenshot%202021-09-14%20at%2010.43.47%20PM.png)

# %%
class Solution:
    def reverseString(self, s: List[str]) -> None:
        """
        Do not return anything, modify s in-place instead.
        """
        i , j = 0 , len(s) - 1
        while i < j:
            s[i],s[j] = s[j],s[i]
            i += 1
            j -= 1

# %% [markdown]
# ![Screenshot%202021-09-14%20at%2010.44.49%20PM.png](attachment:Screenshot%202021-09-14%20at%2010.44.49%20PM.png)
