# %% [markdown]
# ![Screenshot%202021-10-08%20at%2012.12.56%20AM.png](attachment:Screenshot%202021-10-08%20at%2012.12.56%20AM.png)

# %% [markdown]
# ![Screenshot%202021-10-08%20at%2012.13.06%20AM.png](attachment:Screenshot%202021-10-08%20at%2012.13.06%20AM.png)

# %%
# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next
class Solution:
    def swapPairs(self, head: Optional[ListNode]) -> Optional[ListNode]:
        
        if head == None or head.next == None:
            return head 
        
        subhead = self.swapPairs(head.next.next)
        
        head.next.next = head 
        head = head.next
        head.next.next = subhead
        
        return head

# %% [markdown]
# ![Screenshot%202021-10-08%20at%2012.16.18%20AM.png](attachment:Screenshot%202021-10-08%20at%2012.16.18%20AM.png)
