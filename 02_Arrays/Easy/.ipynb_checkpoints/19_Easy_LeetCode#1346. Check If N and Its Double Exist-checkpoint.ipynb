# %% [markdown]
# ![Screenshot%202021-11-05%20at%2010.15.04%20AM.png](attachment:Screenshot%202021-11-05%20at%2010.15.04%20AM.png)

# %% [markdown]
# ![Screenshot%202021-11-05%20at%2010.15.25%20AM.png](attachment:Screenshot%202021-11-05%20at%2010.15.25%20AM.png)

# %%
class Solution:
    def checkIfExist(self, arr: List[int]) -> bool:
        mydict = {}
        for ele in arr:
            if mydict.get((ele/2)) == 1 or mydict.get((2*ele))==1:
                return True
            else:
                mydict[ele] = 1
        return False

# %% [markdown]
# ![Screenshot%202021-11-05%20at%2010.13.50%20AM.png](attachment:Screenshot%202021-11-05%20at%2010.13.50%20AM.png)
