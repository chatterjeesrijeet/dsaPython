# %% [markdown]
# ![Screenshot%202021-10-26%20at%202.44.39%20AM.png](attachment:Screenshot%202021-10-26%20at%202.44.39%20AM.png)

# %% [markdown]
# ![Screenshot%202021-10-26%20at%202.44.59%20AM.png](attachment:Screenshot%202021-10-26%20at%202.44.59%20AM.png)

# %%
class Solution:
    def reverseWords(self, s: str) -> str:
        
        wordslist = s.split(' ')
        for i,words in enumerate(wordslist):
            wordslist[i] = words[::-1]
        
        print(wordslist)
        
        return ' '.join(wordslist)

# %% [markdown]
# ![Screenshot%202021-10-26%20at%202.45.39%20AM.png](attachment:Screenshot%202021-10-26%20at%202.45.39%20AM.png)
