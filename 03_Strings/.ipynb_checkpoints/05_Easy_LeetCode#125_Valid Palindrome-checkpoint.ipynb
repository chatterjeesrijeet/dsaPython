# %% [markdown]
# ![Screenshot%202021-09-08%20at%208.36.06%20PM.png](attachment:Screenshot%202021-09-08%20at%208.36.06%20PM.png)

# %% [markdown]
# ### Approach 1 :

# %%
class Solution:
    def isPalindrome(self, s: str) -> bool:
        f = ''.join([k.lower() for k in s if k.isalnum()])
        return f == f[::-1]

# %% [markdown]
# ![Screenshot%202021-09-08%20at%208.42.29%20PM.png](attachment:Screenshot%202021-09-08%20at%208.42.29%20PM.png)
