# %% [markdown]
# ![Screenshot%202021-11-09%20at%2010.06.22%20PM.png](attachment:Screenshot%202021-11-09%20at%2010.06.22%20PM.png)

# %% [markdown]
# ![Screenshot%202021-11-09%20at%2010.06.45%20PM.png](attachment:Screenshot%202021-11-09%20at%2010.06.45%20PM.png)

# %%
class Solution:
    def heightChecker(self, heights: List[int]) -> int:
        
        expected = heights[:]
        expected.sort()
        count = 0 
        for i in range(len(expected)):
            if expected[i] != heights[i]:
                count += 1
                
        return count

# %% [markdown]
# ![Screenshot%202021-11-09%20at%2010.07.13%20PM.png](attachment:Screenshot%202021-11-09%20at%2010.07.13%20PM.png)
