# %% [markdown]
# ![Screenshot%202021-09-29%20at%207.39.41%20PM.png](attachment:Screenshot%202021-09-29%20at%207.39.41%20PM.png)

# %% [markdown]
# ![Screenshot%202021-09-29%20at%207.40.04%20PM.png](attachment:Screenshot%202021-09-29%20at%207.40.04%20PM.png)

# %% [markdown]
# ![Screenshot%202021-09-29%20at%207.40.22%20PM.png](attachment:Screenshot%202021-09-29%20at%207.40.22%20PM.png)

# %%
"""
# Definition for a Node.
class Node:
    def __init__(self, x: int, next: 'Node' = None, random: 'Node' = None):
        self.val = int(x)
        self.next = next
        self.random = random
"""

class Solution:
    
    def copyRandomList(self, head: 'Node') -> 'Node':
        
        if head == None:
            return None
        
        temp = head 
        mydict = {}
        
        while temp != None:
            newNode = Node(temp.val)
            mydict[temp] = newNode
        
#             if h == None:
#                 h = newNode
#                 t = newNode
#             else:
#                 t.next = newNode
#                 t = t.next
            
            temp = temp.next
        
        temp = head
        while temp != None:
            t = mydict[temp]
            
            if temp.random != None:
                t.random = mydict[temp.random]
            if temp.next != None:
                t.next =  mydict[temp.next]   
            
            temp = temp.next
        
        return mydict[head]

# %% [markdown]
# ![Screenshot%202021-09-29%20at%207.35.53%20PM.png](attachment:Screenshot%202021-09-29%20at%207.35.53%20PM.png)
