# %% [markdown]
# ![Screenshot%202021-11-05%20at%2012.33.53%20PM.png](attachment:Screenshot%202021-11-05%20at%2012.33.53%20PM.png)

# %% [markdown]
# ![Screenshot%202021-11-05%20at%2012.34.16%20PM.png](attachment:Screenshot%202021-11-05%20at%2012.34.16%20PM.png)

# %%
class Solution:
    def replaceElements(self, arr: List[int]) -> List[int]:
        tillmax = arr[len(arr)-1]
        
        for j in range(len(arr)-2,-1,-1):
            tillmax,arr[j] =  max(arr[j],tillmax),tillmax
        
        arr[len(arr)-1]=-1
        
        return arr

# %% [markdown]
# ![Screenshot%202021-11-05%20at%2012.34.48%20PM.png](attachment:Screenshot%202021-11-05%20at%2012.34.48%20PM.png)
