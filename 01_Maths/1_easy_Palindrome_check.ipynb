# %% [markdown]
# ![Screenshot%202021-09-07%20at%209.42.45%20PM.png](attachment:Screenshot%202021-09-07%20at%209.42.45%20PM.png)

# %% [markdown]
# ### Approach 1 :

# %%
class Solution:
    def isPalindrome(self, x: int) -> bool:
        return str(x) == str(x)[::-1]

# %% [markdown]
# ![Screenshot%202021-09-07%20at%209.43.29%20PM.png](attachment:Screenshot%202021-09-07%20at%209.43.29%20PM.png)
