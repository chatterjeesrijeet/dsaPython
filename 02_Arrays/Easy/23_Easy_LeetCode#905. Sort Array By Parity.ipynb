# %% [markdown]
# ![Screenshot%202021-11-07%20at%202.09.29%20PM.png](attachment:Screenshot%202021-11-07%20at%202.09.29%20PM.png)

# %% [markdown]
# ![Screenshot%202021-11-07%20at%202.11.08%20PM.png](attachment:Screenshot%202021-11-07%20at%202.11.08%20PM.png)

# %%
class Solution:
    def sortArrayByParity(self, nums: List[int]) -> List[int]:
        
        i = 0 
        j = len(nums)-1
        while i < j:
            
            if nums[i]%2 != 0:
                while j > i and nums[j]%2 != 0 and j > 0 :
                    j -= 1
                nums[i],nums[j] = nums[j],nums[i]
            
            i += 1
            
        return nums

# %% [markdown]
# ![Screenshot%202021-11-07%20at%202.07.51%20PM.png](attachment:Screenshot%202021-11-07%20at%202.07.51%20PM.png)

# %% [markdown]
# ### Approach 2 :

# %%
class Solution:
    def sortArrayByParity(self, nums: List[int]) -> List[int]:
        
        ''' Appraoch 1 '''
        
        nums.sort(key = lambda x : x%2)
        
        return nums

# %% [markdown]
# ![Screenshot%202021-11-07%20at%204.10.11%20PM.png](attachment:Screenshot%202021-11-07%20at%204.10.11%20PM.png)

# %% [markdown]
# ![Screenshot%202021-11-07%20at%204.11.04%20PM.png](attachment:Screenshot%202021-11-07%20at%204.11.04%20PM.png)
