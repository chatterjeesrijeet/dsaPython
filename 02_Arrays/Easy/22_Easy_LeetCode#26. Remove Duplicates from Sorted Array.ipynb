# %% [markdown]
# ![Screenshot%202021-11-05%20at%2012.51.14%20PM.png](attachment:Screenshot%202021-11-05%20at%2012.51.14%20PM.png)

# %% [markdown]
# ![Screenshot%202021-11-05%20at%2012.51.33%20PM.png](attachment:Screenshot%202021-11-05%20at%2012.51.33%20PM.png)

# %% [markdown]
# ![Screenshot%202021-11-05%20at%2012.51.50%20PM.png](attachment:Screenshot%202021-11-05%20at%2012.51.50%20PM.png)

# %%
class Solution:
    def removeDuplicates(self, nums: List[int]) -> int:
        n = len(nums)
        i , j = 0 , 0
        while j < n :
            if nums[i] != nums[j]:
                i, nums[i]= i+1,nums[j]
            j += 1
        
        return (i+1)

# %% [markdown]
# ![Screenshot%202021-11-05%20at%2012.52.30%20PM.png](attachment:Screenshot%202021-11-05%20at%2012.52.30%20PM.png)
