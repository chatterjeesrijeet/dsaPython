# %% [markdown]
# ![Screenshot%202021-11-11%20at%204.54.07%20PM.png](attachment:Screenshot%202021-11-11%20at%204.54.07%20PM.png)

# %% [markdown]
# ![Screenshot%202021-11-11%20at%204.54.19%20PM.png](attachment:Screenshot%202021-11-11%20at%204.54.19%20PM.png)

# %%
# Definition for a binary tree node.
# class TreeNode(object):
#     def __init__(self, x):
#         self.val = x
#         self.left = None
#         self.right = None

class Codec:

    def serialize(self, root):
        
        if root == None:
            return 'x'
        
        serializedlefttree = self.serialize(root.left)
        seriealizedrighttree = self.serialize(root.right)
                
        return str(root.val) + ',' + serializedlefttree + ',' + seriealizedrighttree
        

    def deserialize(self, data):
        root, index = self.deserializehelp(data.split(','),0)
        return root 
    
    
    def deserializehelp(self, data, index):
        
        if data[index] == 'x' :
            return None,index+1
        
        root = TreeNode(data[index])
        
        index += 1
        
        root.left,index = self.deserializehelp(data,index)
        root.right,index = self.deserializehelp(data,index)
        
        
        return root,index

# Your Codec object will be instantiated and called as such:
# ser = Codec()
# deser = Codec()
# ans = deser.deserialize(ser.serialize(root))

# %% [markdown]
# ![Screenshot%202021-11-11%20at%204.57.49%20PM.png](attachment:Screenshot%202021-11-11%20at%204.57.49%20PM.png)
