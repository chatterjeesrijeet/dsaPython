# %% [markdown]
# ![Screenshot%202021-10-26%20at%2010.56.43%20PM.png](attachment:Screenshot%202021-10-26%20at%2010.56.43%20PM.png)

# %% [markdown]
# ![Screenshot%202021-10-26%20at%2010.57.03%20PM.png](attachment:Screenshot%202021-10-26%20at%2010.57.03%20PM.png)

# %% [markdown]
# ![Screenshot%202021-10-26%20at%2010.57.23%20PM.png](attachment:Screenshot%202021-10-26%20at%2010.57.23%20PM.png)

# %% [markdown]
# ![Screenshot%202021-10-26%20at%2010.57.49%20PM.png](attachment:Screenshot%202021-10-26%20at%2010.57.49%20PM.png)

# %%
class Solution:
    def removeDuplicates(self, nums: List[int]) -> int:
        n = len(nums)
        i , j = 0 , 0
        while j < n :
            if nums[i] != nums[j]:
                i += 1
                nums[i] = nums[j]
            j += 1
        
        return (i+1)

# %% [markdown]
# ![Screenshot%202021-10-26%20at%2010.55.13%20PM.png](attachment:Screenshot%202021-10-26%20at%2010.55.13%20PM.png)
