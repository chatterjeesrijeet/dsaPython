# %% [markdown]
# ![Screenshot%202021-10-23%20at%207.16.43%20PM.png](attachment:Screenshot%202021-10-23%20at%207.16.43%20PM.png)

# %% [markdown]
# ![Screenshot%202021-10-23%20at%207.17.06%20PM.png](attachment:Screenshot%202021-10-23%20at%207.17.06%20PM.png)

# %%
class Solution:
    def reverseString(self, s: List[str]) -> None:
        """
        Do not return anything, modify s in-place instead.
        """
        i = 0
        j = len(s)-1
        while i < j:
            s[i],s[j] = s[j],s[i]
            i += 1
            j -= 1

# %% [markdown]
# ![Screenshot%202021-10-23%20at%207.17.41%20PM.png](attachment:Screenshot%202021-10-23%20at%207.17.41%20PM.png)
