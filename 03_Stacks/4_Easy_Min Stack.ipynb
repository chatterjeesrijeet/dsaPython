# %% [markdown]
# ![Screenshot%202021-07-23%20at%204.33.38%20PM.png](attachment:Screenshot%202021-07-23%20at%204.33.38%20PM.png)

# %% [markdown]
# ![Screenshot%202021-07-23%20at%204.33.49%20PM.png](attachment:Screenshot%202021-07-23%20at%204.33.49%20PM.png)

# %%
class MinStack:

    def __init__(self):
        """
        initialize your data structure here.
        """
        self.stack = []
        self.mins = []

    def push(self, val: int) -> None:
        self.stack.append(val)
        if len(self.mins) == 0 or val <= self.mins[-1]:   
            ## it must be less than equal to self.mins[-1]
            ##  because if min number has appeared twice it should be there in min list twice as well 
            ## so that when you delete the first instance you should still have the minimum
            self.mins.append(val)
        

    def pop(self) -> None:
        popped = self.stack.pop()
        if popped == self.mins[-1]:
            self.mins.pop()

    def top(self) -> int:
        if len(self.stack) == 0:
            return -1
        return self.stack[-1]
        

    def getMin(self) -> int:
        if len(self.mins)==0:
            return "INVALID REQUEST"
        return self.mins[-1]

# %%
ms = MinStack()
print(ms.push(2))
print(ms.push(0))
print(ms.push(3))
print(ms.push(0))
print(ms.getMin())
print(ms.pop())
# Out:
# None
# None
# None
# None
# 0
# None

# %%
print(ms.getMin())
print(ms.pop())
# Out:
# 0
# None

# %%
print(ms.getMin())
print(ms.pop())
# Out:
# 0
# None

# %% [markdown]
# ![Screenshot%202021-07-24%20at%2012.46.06%20AM.png](attachment:Screenshot%202021-07-24%20at%2012.46.06%20AM.png)
