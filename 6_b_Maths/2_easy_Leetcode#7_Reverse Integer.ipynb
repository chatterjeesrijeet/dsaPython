# %% [markdown]
# ![Screenshot%202021-09-10%20at%202.50.06%20PM.png](attachment:Screenshot%202021-09-10%20at%202.50.06%20PM.png)

# %% [markdown]
# ![Screenshot%202021-09-10%20at%202.50.25%20PM.png](attachment:Screenshot%202021-09-10%20at%202.50.25%20PM.png)

# %%
class Solution:
    def reverse(self, x: int) -> int:
        
        neg = False
        if x < 0 :
            neg = True
            x = x * -1
        reversed_num = 0 
        while x > 0:
            rem = x % 10
            reversed_num = reversed_num * 10  + rem
            x = x // 10
        if neg == True:
            reversed_num *= -1
            
        if reversed_num >= (-2**31) and reversed_num <=((2**31)+1):
            pass
        else:
            reversed_num =  0
        
    
        return reversed_num

# %% [markdown]
# ![Screenshot%202021-09-10%20at%202.50.41%20PM.png](attachment:Screenshot%202021-09-10%20at%202.50.41%20PM.png)
