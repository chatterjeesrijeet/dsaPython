# %% [markdown]
# ![Screenshot%202021-09-18%20at%203.58.17%20AM.png](attachment:Screenshot%202021-09-18%20at%203.58.17%20AM.png)

# %% [markdown]
# ![Screenshot%202021-09-18%20at%203.58.35%20AM.png](attachment:Screenshot%202021-09-18%20at%203.58.35%20AM.png)

# %%
class Solution:
    def findDuplicate(self, nums: List[int]) -> int:
        nums.sort()
        
        for i in range(len(nums)-1):
            if nums[i] == nums[i+1]:
                return nums[i]
        return -1

# %% [markdown]
# ![Screenshot%202021-09-18%20at%203.59.52%20AM.png](attachment:Screenshot%202021-09-18%20at%203.59.52%20AM.png)
