# %% [markdown]
# ![Screenshot%202021-10-23%20at%207.34.27%20PM.png](attachment:Screenshot%202021-10-23%20at%207.34.27%20PM.png)

# %% [markdown]
# ![Screenshot%202021-10-23%20at%207.35.22%20PM.png](attachment:Screenshot%202021-10-23%20at%207.35.22%20PM.png)

# %%
class Solution:
    def arrayPairSum(self, nums: List[int]) -> int:
        
        nums.sort()
        sum = 0 
        for i in range(0,len(nums),2):
            sum = sum + nums[i]
        return sum

# %% [markdown]
# ![Screenshot%202021-10-23%20at%207.32.25%20PM.png](attachment:Screenshot%202021-10-23%20at%207.32.25%20PM.png)
