# %% [markdown]
# ![Screenshot%202021-10-07%20at%202.01.27%20AM.png](attachment:Screenshot%202021-10-07%20at%202.01.27%20AM.png)

# %% [markdown]
# ![Screenshot%202021-10-07%20at%202.01.46%20AM.png](attachment:Screenshot%202021-10-07%20at%202.01.46%20AM.png)

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def buildTree(self, inorder: List[int], postorder: List[int]) -> Optional[TreeNode]:
        return self.buildTreeHelp(inorder,0,len(inorder)-1,postorder,0,len(postorder)-1)
    
    def buildTreeHelp(self,inorder,sindex1,eindex1,postorder,sindex2,eindex2):
        
        if sindex1 > eindex1:
            return None
        
        if sindex1 == eindex1:
            return TreeNode(inorder[sindex1])
        
        
        root = None
        bindex = -1
        
        for j in range(eindex2,-1,-1):
            
            ele = postorder[j]

            i = sindex1

            while i <= eindex1:
                if inorder[i] == ele:
                    bindex = i
                    newNode = TreeNode(ele)
                    root = newNode
                    break
                i += 1
            
            if root != None:
                break
        
        root.left = self.buildTreeHelp(inorder,sindex1,(bindex-1),postorder,sindex2,(eindex2-1))
        root.right = self.buildTreeHelp(inorder,(bindex+1),eindex1,postorder,sindex2,(eindex2-1)) 
        
        return root
    
#         if len(inorder) == 1:
#             return TreeNode(inorder[0])
        
#         if len(inorder) ==0:
#             return None
        
#         root = None
        
#         for ele in postorder:
#             if ele in inorder:
#                 index = inorder.index(ele)
#                 newNode = TreeNode(ele)
#                 root = newNode
                
#         root.left = self.buildTree(inorder[:index],postorder[:-1])
#         root.right = self.buildTree(inorder[index+1:],postorder[:-1])
        
#         return root

# %% [markdown]
# ![Screenshot%202021-10-07%20at%202.03.34%20AM.png](attachment:Screenshot%202021-10-07%20at%202.03.34%20AM.png)
