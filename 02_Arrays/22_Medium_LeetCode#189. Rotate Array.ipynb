# %% [markdown]
# ![Screenshot%202021-10-26%20at%204.18.30%20PM.png](attachment:Screenshot%202021-10-26%20at%204.18.30%20PM.png)

# %% [markdown]
# ![Screenshot%202021-10-26%20at%204.18.46%20PM.png](attachment:Screenshot%202021-10-26%20at%204.18.46%20PM.png)

# %%
class Solution:
    def rotate(self, nums: List[int], k: int) -> None:
        """
        Do not return anything, modify nums in-place instead.
        """
        
        
        k = k %(len(nums))
        i ,j = 0 , len(nums)-k
        
        while k > 0 :
            temp = nums[len(nums)-1]
            for j in range(len(nums)-1,0,-1):
                nums[j] = nums[j-1]
            nums[0] = temp
            k -= 1
            
        return nums

# %% [markdown]
# ![Screenshot%202021-10-26%20at%204.19.09%20PM.png](attachment:Screenshot%202021-10-26%20at%204.19.09%20PM.png)

# %% [markdown]
# ### Approach 2 :

# %%
class Solution:
    def rotate(self, nums: List[int], k: int) -> None:
        
        n, a = len(nums) , [0]*n
        
        for i in range(n):
            a[(i+k)%n] = nums[i]
        
        nums[:] = a
        
        return nums

# %% [markdown]
# ![Screenshot%202021-10-26%20at%2011.05.37%20PM.png](attachment:Screenshot%202021-10-26%20at%2011.05.37%20PM.png)

# %% [markdown]
# ![Screenshot%202021-10-26%20at%2011.04.51%20PM.png](attachment:Screenshot%202021-10-26%20at%2011.04.51%20PM.png)

# %% [markdown]
# ### Approach 3 :

# %% [markdown]
# ![Screenshot%202021-10-26%20at%2011.16.06%20PM.png](attachment:Screenshot%202021-10-26%20at%2011.16.06%20PM.png)

# %%
class Solution:
    
    #----------------Approach 3:-------------------------
    
    def reverse(self, nums: list, start: int, end: int) -> None:
        while start < end:
            nums[start], nums[end] = nums[end], nums[start]
            start, end = start + 1, end - 1

    def rotate(self, nums: List[int], k: int) -> None:
        """
        Do not return anything, modify nums in-place instead.
        """
        
        n = len(nums)
        k %= n

        self.reverse(nums, 0, n - 1)
        self.reverse(nums, 0, k - 1)
        self.reverse(nums, k, n - 1)

# %% [markdown]
# ![Screenshot%202021-10-26%20at%2011.19.11%20PM.png](attachment:Screenshot%202021-10-26%20at%2011.19.11%20PM.png)
