# %% [markdown]
# ![Screenshot%202021-07-28%20at%2010.55.18%20AM.png](attachment:Screenshot%202021-07-28%20at%2010.55.18%20AM.png)

# %% [markdown]
# ![Screenshot%202021-07-28%20at%2010.55.41%20AM.png](attachment:Screenshot%202021-07-28%20at%2010.55.41%20AM.png)

# %% [markdown]
# ![Screenshot%202021-07-28%20at%2010.56.08%20AM.png](attachment:Screenshot%202021-07-28%20at%2010.56.08%20AM.png)

# %%
def createstack():
    return []

def push(st,val):
    st.append(val)

def pop(st):
    return st.pop()

def top(st):
    return st[len(st)-1]

def isEmpty(st):
    return len(st)==0

def size(st):
    return len(st)

def reverse(st):
    
    if len(st) <= 1:
        return st
    
    popped = st.pop()
    smallprob = reverse(st)
    pushattheend(st,popped)
    
    return st

def pushattheend(st,ele):
    
    if len(st)==0:
        st.push(ele)
        
    popped = st.pop()
    pushattheend(st,ele)
    st.push(popped)
    
    return st
